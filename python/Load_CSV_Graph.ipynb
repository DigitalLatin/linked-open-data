# %% [markdown]
# ## Example Loading CSV into Graph

# %% [markdown]
# ### Using Pandas and RDFLib

# %%
import pandas as pd

from rdflib import Graph, Literal, BNode, Namespace, RDF, URIRef
from rdflib.namespace import DC, FOAF

# %%
g = Graph()
df_authors = pd.read_csv("../csv/author-authorities-export.csv", encoding="utf-8")

def load_person(r):
    # Create an identifier to use as the subject for person.
    person = URIRef(r['DLL Page Link'])
    
    # Add triples using store's add method.
    g.add( (person, RDF.type, FOAF.Person) )
    g.add( (person, FOAF.name, Literal(r['Authorized Name'])) )
    g.add( (person, FOAF.name, Literal(r['Author Name Native Language'])) )
    g.add( (person, FOAF.name, Literal(r['Author Name Latin'])) )
    g.add( (person, FOAF.name, Literal(r['Author Name English'])) )


for row in df_authors.to_dict(orient="records"):
    load_person(row)


print("Graph loaded")
# Out:
# Graph loaded

# %% [markdown]
# ### SPARQL query example

# %%
qres = g.query(
    """SELECT DISTINCT ?a
       WHERE {
          # ?a foaf:name "Hilary, Saint, Archbishop of Arles"
       }""",
    initNs={ 'foaf': FOAF })

for row in qres:
    print("%s" % row)
# Out:
# https://catalog.digitallatin.org/dll-author/A5137

# %%
qres = g.query(
    """SELECT DISTINCT ?a
       WHERE {
          # ?a foaf:name "Hilarius Arelatensis"
       }""",
    initNs={ 'foaf': FOAF })

for row in qres:
    print("%s" % row)
# Out:
# https://catalog.digitallatin.org/dll-author/A5137

# %% [markdown]
# ### Example of serializing graph to turtle

# %%
#import xml.dom.minidom
#dom = xml.dom.minidom.parseString(g.serialize(format='pretty-xml'))
#print(dom.toprettyxml())
g.serialize(format='turtle')
# Out:
# b'@prefix ns1: <http://xmlns.com/foaf/0.1/> .\n@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix xml: <http://www.w3.org/XML/1998/namespace> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n<https://catalog.digitallatin.org/dll-author/> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double .\n\n<https://catalog.digitallatin.org/dll-author/A1868> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Herryson, Joannes",\n        "Joannes Herryson",\n        "John Herryson" .\n\n<https://catalog.digitallatin.org/dll-author/A1870> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Johannes Stratford",\n        "John Stratford",\n        "Stratford, John, -1348" .\n\n<https://catalog.digitallatin.org/dll-author/A2181> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Nicomachus, of Gerasa" .\n\n<https://catalog.digitallatin.org/dll-author/A2491> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Anaritius, -approximately 922" .\n\n<https://catalog.digitallatin.org/dll-author/A2492> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Strecker, Karl, 1861-1945" .\n\n<https://catalog.digitallatin.org/dll-author/A2493> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Simon, Johann Georg, approximately 1636-1696" .\n\n<https://catalog.digitallatin.org/dll-author/A2494> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Komarek, Giovanni Giacomo, 1648-1706" .\n\n<https://catalog.digitallatin.org/dll-author/A2495> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Pr\xc3\xa9chac, Fran\xc3\xa7ois" .\n\n<https://catalog.digitallatin.org/dll-author/A2508> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Ignatios, the Deacon, approximately 775-approximately 848" .\n\n<https://catalog.digitallatin.org/dll-author/A2755> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Alberico da Marcellise" .\n\n<https://catalog.digitallatin.org/dll-author/A2868> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Aquilius Niger, Quintus",\n        "Quintus Aquilius Niger" .\n\n<https://catalog.digitallatin.org/dll-author/A2869> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Marianus" .\n\n<https://catalog.digitallatin.org/dll-author/A2870> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Salvius Iulianus, Saluius Iulianus",\n        "Salvius Julianus" .\n\n<https://catalog.digitallatin.org/dll-author/A2871> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Marcellus, Marcus Claudius, -45 B.C.",\n        "Marcus Claudius Marcellus, M. Claudius Marcellus" .\n\n<https://catalog.digitallatin.org/dll-author/A2872> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Lentulus Spinther, Publius Cornelius, born c. 43 B.C.",\n        "Publius Cornelius Lentulus Spinther, P. Cornelius Spinther" .\n\n<https://catalog.digitallatin.org/dll-author/A2873> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Claudius Saturninus",\n        "Saturninus, Claudius, active 2nd century A.D." .\n\n<https://catalog.digitallatin.org/dll-author/A2874> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Metellus, Quintus Caecilius Nepos, -56",\n        "Quintus Caecilius Nepos Metellus, Q. Caecilius Metellus Nepos" .\n\n<https://catalog.digitallatin.org/dll-author/A2875> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Metellus Celer, Q. Caecilius",\n        "Quintus Caecilius Metellus Celer, Q. Caecilius Metellus Celer" .\n\n<https://catalog.digitallatin.org/dll-author/A2876> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Papirius Iustus",\n        "Papirius Iustus, active 2nd century A.D." .\n\n<https://catalog.digitallatin.org/dll-author/A2877> a ns1:Person ;\n    ns1:name "NaN"^^xsd:double,\n        "Iunius Mauricianus",\n        "Mauricianus, Iunius, active 2nd century A.D." .\n\n<https://catalog.digitallatin.org/dll-author/A2878> a ns1:Person ;\n    ns1:name "NaN ...

# %% [markdown]
# ### Example of setting namespace

# %%
# Example of setting a namespace

from rdflib import Namespace

n = Namespace("https://catalog.digitallatin.org/dll-author/")

print(n.bob)
print(n.eve)
print(n.A5137)
# Out:
# https://catalog.digitallatin.org/dll-author/bob
# https://catalog.digitallatin.org/dll-author/eve
# https://catalog.digitallatin.org/dll-author/A5137
